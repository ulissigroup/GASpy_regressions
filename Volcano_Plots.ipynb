# %% [markdown]
# # Volcano_Plots.ipynb
# Author:  Kevin Tran <ktran@andrew.cmu.edu>
#
# This python notebook takes regression models createdy by `regress.ipynb` and uses them to construct volcano plots.

# %% [markdown]
# ## Initializations/Data Management

# %% [markdown]
# ###### Importing

# %%
from pprint import pprint   # for debugging
import sys
import math
import copy
import numpy as np
import pandas as pd
from pymatgen.matproj.rest import MPRester
sys.path.append('..')
from gaspy.utils import vasp_settings_to_str
from gas_pull import GASPull
import dill as pickle
pickle.settings['recurse'] = True     # required to pickle lambdify functions
import matplotlib.pyplot as plt
from plotly.offline import init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.plotly as py
import plotly.graph_objs as go
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ###### Load GASdb data

# %%
# Location of the *.db file
DB_LOC = '/global/cscratch1/sd/zulissi/GASpy_DB/'  # Cori
#DB_LOC = '/Users/KTran/Nerd/GASpy'                 # Local

# Calculation settings we want to look at
VASP_SETTINGS = vasp_settings_to_str({})

# Pull the data from the Local database
GAS_PULL = GASPull(DB_LOC, VASP_SETTINGS, split=False)
ROWS = GAS_PULL.rows
MPIDS = np.unique([row.mpid for row in ROWS])
ADS = np.unique([row.adsorbate for row in ROWS])

# %% [markdown]
# ###### Filter GASdb data

# %%
# We store all of the adsorption energies in the nested dictionary, `ENERGIES`. The first
# tier has keys for each adsorbate, and the second tier has keys for each mpid-facet pairing.
# Note that we only store the minimum (i.e., strongest) adsorption energy for each facet.
ENERGIES = dict.fromkeys(ADS, {})
with MPRester("MGOdX3P4nI18eKvE") as m:
    for ads in ADS:
        for mpid in MPIDS:
            bulk_formula = m.get_structure_by_material_id(mpid).formula
            facets = np.unique([row.miller for row in ROWS
                                if row.adsorbate == ads
                                and row.mpid == mpid])
            for facet in facets:
                energies = [row.energy for row in ROWS
                            if row.adsorbate == ads
                            and row.mpid == mpid
                            and row.miller == facet]
                if energies:
                    ENERGIES[ads][(bulk_formula, facet)] = np.min(energies)

# %% [markdown]
# ###### Filter GASdb data (OER)

# %%
# Filter data again, but do it for OER. Because OER is a special snowflake. Note that this
# `OER_ENERGIES` dictionary is not nested.
OER_ENERGIES = {}
with MPRester("MGOdX3P4nI18eKvE") as m:
    for mpid in MPIDS:
        bulk_formula = m.get_structure_by_material_id(mpid).formula
        facets = np.unique([row.miller for row in ROWS
                            if row.adsorbate == 'O'
                            and row.mpid == mpid])
        for facet in facets:
            o_energies = [row.energy for row in ROWS
                          if row.adsorbate == 'O'
                          and row.mpid == mpid
                          and row.miller == facet]
            oh_energies = [row.energy for row in ROWS
                           if row.adsorbate == 'OH'
                           and row.mpid == mpid
                           and row.miller == facet]
            if o_energies and oh_energies:
                OER_ENERGIES[(bulk_formula, facet)] = np.min(o_energies)-np.min(oh_energies)

# %% [markdown]
# ###### Load GASpy_regression Models

# %%
# Define the models you want to pull out here
#MODELS = dict.fromkeys(('GBE', 'LR', 'GP', 'TPOT'))
MODELS = {'GP': None}

# This loop will pull each model out of their pickle. File names are hard-coded, so
# make sure they match up with the pickles created in `regress.ipynb`
for model in MODELS:
    MODELS[model] = {}
    pkl = pickle.load(open('pkls/CoordcountAds_Energy_%s.pkl' % model, 'r'))
    MODELS[model]['model'] = pkl['model']
    MODELS[model]['pre_processors'] = pkl['pre_processors']

# %% [markdown]
# ###### Load Literature Volcanoes

# %%
# The `CURVES` dictionary will hold a function for each reaction we plan to look at.
# These functions will predict kinetic properties from adsorption energies.
CURVES = {}
# The `POINTS` dictionary will hold the incumbent data points from each volcano plot
POINTS = {}

def make_curve(_params, rxn):
    '''
    Since we have a variable number of reactions, we need to populate `CURVES` using
    a function factory. `make_curve` is this function factory.
    
    Inputs:
        _params     A list of the parameters needed to generate the curve/model
        rxn         A string indicating the system type, which should tell us which
                    model to generate
    '''
    def calc_lin_curve(e):
        ''' `calc_lin_curve` is the linear function we'll be making over and over again '''
        if e < _params['cutoff']:
            return e*_params['LHS']['slope'] + _params['LHS']['intercept']
        else:
            return e*_params['RHS']['slope'] + _params['RHS']['intercept']
    def calc_exp_curve(e):
        ''' `calc_exp_curve` is the expratic function we'll be making over and over again '''
        if e < _params['cutoff']:
            return np.exp(e*_params['LHS']['slope'] + _params['LHS']['intercept'])
        else:
            return np.exp(e*_params['RHS']['slope'] + _params['RHS']['intercept'])
    
    if rxn in ['OER', 'ORR']:
        return calc_lin_curve
    elif rxn in ['HER']:
        return calc_exp_curve
    else:
        raise Exception('Not a known system type')

# Populate `CURVES` and `POINTS` for each reaction
for rxn in ['OER', 'ORR', 'HER']:
    # Use pandas to pull a dataframe of our information. This script
    # is reliant on the structure of the Excel file, so keep it kosher.
    # Note also that the name of the Excel sheet must match the string
    # value in this loop's iterator.
    #df = pd.read_excel('/Users/KTran/Google_Drive/Manuscripts/GASpy/figures/' + \
    df = pd.read_excel('/global/project/projectdirs/m2755/GASpy/GASpy_regressions/' + \
                       'Literature_Volcano_Data.xlsx',
                       sheetname=rxn)
    
    # Pull out the information for `POINTS'
    POINTS[rxn] = {'y': df.iloc[:, 0].get_values(),
                   'x': df.iloc[:, 1].get_values(),
                   'labels': df.index.tolist()}
    
    # Do some fancy footwork to find `cutoff`, which is the x-value of
    # the vertex of the volcano curve.
    ind = (df.iloc[:, 2] == 'Vertex')
    cutoff = df.iloc[:, 3][ind].get_values()[0]
    # Find the slope and intercepts of the lines for both the LHS and
    # RHS of the volcano
    params = {'LHS': {}, 'RHS': {}}
    params['LHS']['slope'] = df.iloc[0, 5]
    params['LHS']['intercept'] = df.iloc[0, 6]
    params['RHS']['slope'] = df.iloc[0, 9]
    params['RHS']['intercept'] = df.iloc[0, 10]
    params['cutoff'] = cutoff
    # Pass the slopes and intercepts to our function factory to create the curve
    CURVES[rxn] = make_curve(params, rxn)

# %% [markdown]
# ## Plotting

# %% [markdown]
# ###### ORR

# %%
# The domain to plot over
x = np.linspace(0.8, 2.4, 100).tolist()

# Let's make a plot for each model
for model in MODELS:
    traces = []
    
    # Add the volcano line
    #traces.append(go.Scatter(x=x,
    #                         y=map(CURVES['ORR'], x),
    #                         mode='lines',
    #                         name='Volcano Line'))
 
    # Add the data points from the original volcano
    traces.append(go.Scatter(x=POINTS['ORR']['x'],
                             y=POINTS['ORR']['y'],
                             mode='markers',
                             text=POINTS['ORR']['labels'],
                             name='Literature'))
    
    # Add our predictions
    traces.append(go.Scatter(x=ENERGIES['O'].values(),
                             y=map(CURVES['ORR'], ENERGIES['O'].values()),
                             mode='markers',
                             text=['\n'.join(key) for key in ENERGIES['O'].keys()],
                             name='GASpy Predictions'))
    
    # Format and plot
    layout = go.Layout(xaxis=dict(title='$\Delta E_O [eV]$'),
                       yaxis=dict(title='$Activity$'),
                       title='ORR Volcano Projections using CoordcountAds (%s)' % model)
    iplot(go.Figure(data=traces, layout=layout))
# Out:
# <div id="c7506b65-40bd-4d79-91e4-6ee2a92c4bec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c7506b65-40bd-4d79-91e4-6ee2a92c4bec", [{"name": "Literature", "text": ["Fe", "W", "Mo", "Co", "Ru", "Ni", "Rh", "Cu", "Ir", "Pd", "Pt", "Ag", "Au"], "mode": "markers", "y": [-2.28159, -2.09142, -2.36334, -1.5638, -1.48772, -1.35465, -1.14044, -1.11238, -0.85034, -0.560224, -0.450733, -0.803486, -1.93248], "x": [-2.05709, -1.61425, -0.893852, -0.218557, -0.0452692, 0.339715, 0.446079, 1.20577, 1.00458, 1.53423, 1.58261, 2.12971, 2.75157], "type": "scatter"}, {"name": "GASpy Predictions", "text": ["Si2 Ni2\n(1.2.1)", "V1 Pt2\n(1.1.0)", "Ga2 Cu6\n(0.0.1)", "In1 Cu1 Pd2\n(1.1.1)", "Si4 Ir4\n(1.1.0)", "In4 Ag2\n(1.1.0)", "V4 Co4 Si4\n(1.0.0)", "Ag3 Pd1\n(1.1.2)", "Sn2 Pt1\n(1.1.1)", "Cu2 Pd1 Au1\n(2.1.0)", "In4 Ag2\n(1.0.1)", "In1 Cu1 Pd2\n(2.1.0)", "Ga10 Rh6\n(0.0.1)", "V4 Sn4 Rh8\n(1.0.1)", "Si2 Ni1\n(2.1.0)", "In3 Pd2\n(0.0.1)", "N4\n(1.1.0)", "Al2 Fe1 Ir1\n(2.1.0)", "Ga1 Cu1 Rh2\n(2.1.0)", "Co2 Sn4\n(1.1.0)", "V6 N3\n(0.0.1)", "In1 Sb1\n(1.1.1)", "Ni2 Pt2\n(2.1.1)", "V6 Ni2\n(1.0.0)", "Ga2 Pt6\n(1.1.0)", "Ni2 Sb4\n(1.0.0)", "Si3 Pd6\n(0.0.1)", "In2 Au1\n(1.1.1)", "Re2 Rh6\n(0.0.1)", "Ni2 H1\n(1.0.1)", "V6 Ga2\n(1.0.0)", "Al1 Ga1 N2\n(2.1.1)", "Sn4 Pd4\n(1.0.2)", "Ni4 W1\n(1.1.1)", "Ga18 Ir4\n(0.0.1)", "Ga4 Au4\n(1.0.0)", "Ga1 Co1\n(2.1.0)", "Si4 Rh4\n(1.0.0)", "Al3 V1\n(1.1.0)", "V1 Ga1 Ni2\n(2.1.0)", "Fe1 Si2\n(1.0.0)", "In2 Sb2\n(1.0.2)", "Ga2 N2\n(1.1.1)", "Ga1 Cu1 Pt2\n(1.1.1)", "Ga4 Os2\n(0.1.0)", "Al1 Au2\n(1.1.2)", "Co2 Re6\n(0.0.1)", "Re6 Pt2\n(0.0.1)", "In2 Sb2\n(0.0.1)", "Pd1 Au3\n(2.1.1)", "V2 Ir2\n(1.0.1)", "Fe1 Si2\n(2.1.0)", "Fe3 Pt1 N1\n(1.1.1)", "Si4 Pt4\n(1.0.0)", "Co1 Si2\n(2.1.0)", "Sb1 Pd3\n(2.1.0)", "In12 Ir4\n(1.0.0)", "V1 Co1 Sb1\n(2.1.0)", "Fe8 W4\n(0.0.1)", "Ni2 Sn4 Au1\n(1.0.1)", "Sn2 Pt1\n(1.0.0)", "Co3 Sn3\n(0.0.1)", "Sn1 Pt3\n(1.1.1)", "Si2 Ni2\n(2.1.0)", "Al4 Pt4\n(1.0.0)", "Si6 H18 N2\n(0.0.1)", "Al2 Os1\n(1.1.2)", "Fe2 Pd2\n(2.1.1)", "Cu2 Sn2\n(1.1.1)", "Si4 Pd4\n(1.1.1)", "In2 Sb2\n(1.0.1)", "Si4 Os4\n(1.0.0)", "V2 Sb4\n(1.0.1)", "Al2 Fe1 Ni1\n(2.1.0)", "In12 Ir4\n(0.0.1)", "W4 N8\n(0.0.1)", "Al4 Cu2\n(1.0.1)", "Sn2 Ir1\n(1.0.0)", "In2 Pt1\n(1.1.1)", "In3 Ni2\n(1.1.1)", "Si4 Os4\n(1.1.1)", "Al18 Co4\n(0.0.1)", "Al2 Co1 Ir1\n(2.1.0)", "Si2 Ni2\n(2.1.1)", "Al18 Rh4\n(0.0.1)", "Ni2 Pt2\n(1.0.0)", "In2 Au3\n(0.0.1)", "Al1 Cu1 Pt2\n(1.1.1)", "In1 Ag3\n(1.1.1)", "Si2 Cu6\n(0.0.1)", "Fe3 Co1\n(1.1.1)", "Cu1 Ni1 Sb2\n(1.1.1)", "Al12 Fe2\n(0.0.1)", "Ga3 Ni5\n(0.0.1)", "In2 Au1\n(1.1.0)", "Re6 Pd2\n(1.0.0)", "Al2 V6\n(1.0.0)", "V1 Pd2\n(1.1.0)", "Ag3 Pd1\n(1.1.0)", "V1 Cu1 Rh2\n(2.1.0)", "Co1 Sn1 Rh2\n(1.1.2)", "In2 N2\n(1.1.0)", "In2 Au3\n(1.0.0)", "Al1 Fe1 Rh2\n(2.1.0)", "Si4 Pd12\n(0.0.1)", "Sn2\n(1.1.1)", "Fe1 Ni3\n(1.1.1)", "Si8 Sb8 Pt8\n(0.0.1)", "Fe1 Pt1\n(2.1.1)", "Al4 Cu2\n(1.1.0)", "Al2 Co1 Os1\n(2.1.0)", "Co6 Pt2\n(0.0.1)", "Ga3 Ag6\n(1.0.1)", "In1 Sb1\n(1.1.0)", "V2 Rh6\n(0.0.1)", "Pt2 W1\n(1.1.2)", "Re4 Si4\n(1.1.1)", "V2 Re1 W1\n(2.1.0)", "Al1 Cu1 Au2\n(2.1.0)", "Ni3 Sn4\n(1.1.0)", "Al2 Ir1 Os1\n(2.1.0)", "Si3 Pd6\n(1.1.1)", "Si2 Ni2\n(0.1.0)", "V2 Rh2\n(1.0.1)", "Sb1 Pt7\n(1.0.0)", "Co4 N2\n(0.1.0)", "Ga1 Sb1\n(2.1.0)", "Fe2 Ni2\n(2.0.1)", "Cu2 Au2\n(2.1.1)", "Sn2 Ir1\n(1.1.0)", "Si2 W1\n(1.1.0)", "Cu1 Au3\n(1.1.1)", "V1 Fe1 Sb1\n(1.1.0)", "Al1 Fe2 W1\n(2.1.0)", "Ga4 Os2\n(0.0.1)", "Fe1 Si2\n(1.0.1)", "Ir3 Rh1\n(1.0.1)", "V6 Sb4\n(1.0.1)", "V4 Ir4\n(0.0.1)", "Co2 Sb2\n(2.1.0)", "V6 Sb2\n(1.0.0)", "Ni2 Pt2\n(1.0.1)", "Ga1 Ni1 Rh2\n(2.1.0)", "In1 Cu1 Pt2\n(1.1.1)", "In3 Ni3\n(0.0.1)", "In1 Pt3\n(1.1.1)", "Fe6 Re2\n(0.0.1)", "Fe1 Sn1 Rh2\n(1.1.2)", "Sb2 Pt2\n(1.0.0)", "Re6 Pd2\n(0.0.1)", "Cu1 Pt1\n(2.1.1)", "Sn2\n(1.0.0)", "Pt2 W1\n(1.1.0)", "Sn4 Pd8\n(0.0.1)", "Co2 Re6\n(1.0.0)", "Sb2 Ir2\n(1.1.0)", "Sb2 Ir2\n(1. ...

# %% [markdown]
# ###### OER

# %%
# The domain to plot over
x = np.linspace(-2.5, 3, 100).tolist()

# Let's make a plot for each model
for model in MODELS:
    traces = []
    
    # Add the volcano line
    #traces.append(go.Scatter(x=x,
    #                         y=map(CURVES['OER'], x),
    #                         mode='lines',
    #                         name='Volcano Line'))
 
    # Add the data points from the original volcano
    traces.append(go.Scatter(x=POINTS['OER']['x'],
                             y=POINTS['OER']['y'],
                             mode='markers',
                             text=POINTS['OER']['labels'],
                             name='Literature'))
    
    # Add our predictions
    # TODO:  Turn our adsorption energies into gibbs' energies
    traces.append(go.Scatter(x=OER_ENERGIES.values(),
                             y=map(CURVES['OER'], OER_ENERGIES.values()),
                             mode='markers',
                             text=['\n'.join(key) for key in OER_ENERGIES.keys()],
                             name='GASpy Predictions'))
    
    # Format and plot
    layout = go.Layout(xaxis=dict(title='$\Delta G_O-\Delta G_{OH} [eV]$'),
                       yaxis=dict(title='$Overpotential [V] for j = 1 mA/cm^2_{cat}$',
                                  autorange='reversed'),
                       title='OER Volcano Projections using CoordcountAds (%s)' % model)
    iplot(go.Figure(data=traces, layout=layout))
# Out:
# <div id="fc3f79a6-ab23-4603-abf0-c6ac3e283d89" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fc3f79a6-ab23-4603-abf0-c6ac3e283d89", [{"name": "Literature", "text": ["LaCrO3", "PtO2", "IrO2 110", "IrO2 100", "NiCoOx", "CoOx-(a)", "IrOx/SrIrO3", "NiOx", "LaCoO3", "CoFeOx", "NiFeOx", "FeCoW", "LaNiO3", "LaMnO3", "LaFeO3 FM", "LaFeO3 GAFM", "TiO2"], "mode": "markers", "y": [0.72, 0.6, 0.55, 0.48, 0.38, 0.4, 0.23, 0.43, 0.43, 0.4, 0.35, 0.3500000000000001, 0.43, 0.56, 0.49, 0.49, 0.84], "x": [0.98, 1.07, 1.38, 1.42, 1.48, 1.49, 1.5, 1.56, 1.59, 1.6, 1.62, 1.63, 1.84, 1.98, 1.99, 2.11, 2.48], "type": "scatter"}, {"name": "GASpy Predictions", "text": ["V1 Pt2\n(1.1.0)", "Ga2 Cu6\n(0.0.1)", "In1 Cu1 Pd2\n(1.1.1)", "In4 Ag2\n(1.0.1)", "In1 Cu1 Pd2\n(2.1.0)", "V4 Sn4 Rh8\n(1.0.1)", "In3 Pd2\n(0.0.1)", "In2 Sb2\n(1.0.1)", "Ga1 Cu1 Rh2\n(2.1.0)", "Co2 Sn4\n(1.1.0)", "In1 Sb1\n(1.1.1)", "V6 Ni2\n(1.0.0)", "Ga2 Pt6\n(1.1.0)", "Ni2 Sb4\n(1.0.0)", "In2 Au1\n(1.1.1)", "Si4 Rh4\n(1.0.0)", "Ga1 Cu1 Pt2\n(1.1.1)", "Ga4 Os2\n(0.1.0)", "In2 Sb2\n(0.0.1)", "Fe1 Si2\n(2.1.0)", "Fe3 Pt1 N1\n(1.1.1)", "Fe8 W4\n(0.0.1)", "Co3 Sn3\n(0.0.1)", "Sn1 Pt3\n(1.1.1)", "Al2 Os1\n(1.1.2)", "Cu2 Sn2\n(1.1.1)", "Si4 Os4\n(1.0.0)", "V2 Sb4\n(1.0.1)", "W4 N8\n(0.0.1)", "Al4 Cu2\n(1.0.1)", "In2 Pt1\n(1.1.1)", "Ni2 Pt2\n(1.0.0)", "Al1 Cu1 Pt2\n(1.1.1)", "In1 Ag3\n(1.1.1)", "Si2 Cu6\n(0.0.1)", "Ga3 Ni5\n(0.0.1)", "In2 Au1\n(1.1.0)", "Al2 V6\n(1.0.0)", "V1 Pd2\n(1.1.0)", "Ag3 Pd1\n(1.1.0)", "In2 Au3\n(1.0.0)", "Al2 Co1 Os1\n(2.1.0)", "Ag1 Au3\n(1.1.1)", "Ga3 Ag6\n(1.0.1)", "In1 Sb1\n(1.1.0)", "Ga4 Os2\n(0.0.1)", "Re4 Si4\n(1.1.1)", "V2 Re1 W1\n(2.1.0)", "Ni3 Sn4\n(1.1.0)", "V2 Rh2\n(1.0.1)", "Sb1 Pt7\n(1.0.0)", "Cu1 Ni1 Sb2\n(1.1.1)", "Cu2 Au2\n(2.1.1)", "Sn2 Ir1\n(1.1.0)", "Si2 W1\n(1.1.0)", "Cu1 Au3\n(1.1.1)", "Ir3 Rh1\n(1.0.1)", "Ni2 Pt2\n(1.0.1)", "In3 Ni3\n(0.0.1)", "Fe6 Re2\n(0.0.1)", "Fe1 Sn1 Rh2\n(1.1.2)", "Sb2 Pt2\n(1.0.0)", "Fe1 Pt1\n(2.1.1)", "Fe1 Ni1 Pt2\n(1.1.1)", "In2 Pt1\n(1.1.0)", "Sb2 Ir2\n(1.1.0)", "Ni4 W1\n(0.0.1)", "Fe3 Pd1 N1\n(1.1.1)", "Co2 Sn4\n(1.0.1)", "Ga10 Rh6\n(0.0.1)", "Ga2 Cu1\n(1.0.1)", "In3 Pd2\n(1.0.0)", "V2 Sb4\n(1.1.0)", "V6 N3\n(1.0.0)", "In2 Pt1\n(1.0.0)", "Al1 Sb1\n(2.1.0)", "Fe2 Pd2\n(1.0.1)", "Al2 Ag4\n(0.0.1)", "Rh6 W2\n(0.0.1)", "V6 Au2\n(1.0.0)", "Cu1 Pt1\n(1.1.0)", "In12 Rh4\n(0.0.1)", "Fe2 Ni2\n(2.0.1)", "Sn2 Ir1\n(1.1.1)", "Al2 Ag4\n(0.1.0)", "Al1 Au2\n(1.1.0)", "Re2\n(1.1.1)", "V6 Co2\n(1.0.0)", "Al1 V1 Fe1 Co1\n(2.1.0)", "Al12 Ni4\n(0.0.1)", "Ni2 Sb2\n(1.1.1)", "Re2 Rh6\n(0.0.1)", "Co3 Ni1\n(1.1.1)", "V8 Si2 Sb4\n(1.1.0)", "V1 Os1\n(2.1.0)", "Al2 Os1\n(1.1.0)", "Pd1 Au3\n(1.1.1)", "Si2 Ir6\n(1.0.1)", "Sn1 Pd3\n(1.1.1)", "Sn1 Au5\n(1.0.1)", "Al10 W2\n(0.0.1)", "Co2 Sb2\n(1.1.0)", "V6 Si2\n(1.0.0)", "Re2 Ir6\n(0.0.1)", "Fe2 Sb4\n(1.0.1)", "Re6 Ni2\n(0.0.1)", "Cu1 Sn1 Rh2\n(2.1.0)", "In1 Rh1\n(1.1.1)", "In1 Pd2 Au1\n(1.1.1)", "Ag2 Au6\n(1.0.0)", "Ir2 W2\n(0.1.0)", "Co2 Re6\n(0.0.1)"], "mode": "markers", "y": [1.2350660371180138, 1.0526441150889971, 0.7143045046352471, 0.9524967434046714, 0.7582171637051138, 0.4319870287735357, 0.6794604145642555, 0.8573032248328043, 0.9922973934612547, 1.166046303894434, 0.6913717312429265, 1.4230279518829037, 0.6577593143276137, 0.9698256143276046, 0.8815733442998257, 0.7929570162208062, 0.8223940780481529, 1.1018969367373168, 0.6378983897057309, 1.2849771270552488, 1.3098050000257193, 1.4478458887282653, 1.633062844063172, 0.8783589488373247, 0.34529324569829095, 1.132363665577735, 1.3797203346691933, 1.3281557188342419, 1.165843006579891, 1.2230772960026741, 0.7328818273947936, 1.0985207187622184, 0.8346620531176033, 0.6475963755273186, 1.254270613823436, 0.9876645112717313, 0.7126905921545434, 1.6826475886562449, 1.351910988409298, 0.41924350262887156, 0.5654888451538224, 1.4088003383012722, 0.69587623 ...

# %% [markdown]
# ###### HER

# %%
# The domain to plot over
x = np.linspace(-1., 1., 1000).tolist()

# Let's make a plot for each model
for model in MODELS:
    traces = []
    
    # Add the volcano line
    #traces.append(go.Scatter(x=x,
    #                         y=map(CURVES['HER'], x),
    #                         mode='lines',
    #                         name='Volcano Line'))
 
    # Add the data points from the original volcano
    traces.append(go.Scatter(x=POINTS['HER']['x'],
                             y=POINTS['HER']['y'],
                             mode='markers',
                             text=POINTS['HER']['labels'],
                             name='Literature'))
    
    # Add our predictions
    traces.append(go.Scatter(x=ENERGIES['H'].values(),
                             y=map(CURVES['HER'], ENERGIES['H'].values()),
                             mode='markers',
                             text=['\n'.join(key) for key in ENERGIES['H'].keys()],
                             name='GASpy Predictions'))
    
    # Format and plot
    layout = go.Layout(xaxis=dict(title='$\Delta G_H [eV]$'),
                       yaxis=dict(title='$j_0 [A/cm^2]$', type='log'),
                       title='HER Volcano Projections using CoordcountAds (%s)' % model)
    iplot(go.Figure(data=traces, layout=layout))
# Out:
# <div id="77fed80a-9398-45f2-9a54-92f4048c013a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("77fed80a-9398-45f2-9a54-92f4048c013a", [{"name": "Literature", "text": ["Nb", "Mo", "W", "Co", "Ni", "Re", "Pd", "Pt", "Pt(111)", "Pt(111)", "Pt(111)", "Rh", "Ir", "Ir", "MoS2", "Cu", "Au", "Au(111)", "Ag", null], "mode": "markers", "y": [1.54302191067905e-07, 8.47045962577537e-08, 1.30701047960936e-06, 4.85340475878607e-06, 6.30957344480193e-06, 0.00139375374234799, 0.000994659462593751, 0.00235555377526072, 0.000765104806427315, 0.000634345088151937, 0.000436048587209266, 0.000248512842698055, 0.000335414161787261, 0.000191159263605031, 7.6101873558889e-06, 4.17763249481499e-06, 4.02393690862489e-06, 2.51188643150957e-07, 1.45475781084804e-08, null], "x": [-0.560212201591512, -0.369230769230769, -0.428647214854111, -0.271618037135278, -0.271618037135278, -0.322546419098143, -0.140053050397878, -0.0912466843501327, -0.0912466843501327, -0.0997347480106101, -0.0912466843501327, -0.101856763925729, 0.0297082228116709, 0.0297082228116709, 0.0785145888594163, 0.188859416445623, 0.447745358090185, 0.447745358090185, 0.507161803713527, null], "type": "scatter"}, {"name": "GASpy Predictions", "text": ["Si2 Ni2\n(1.2.1)", "V1 Pt2\n(1.1.0)", "Ga2 Cu6\n(0.0.1)", "In1 Cu1 Pd2\n(1.1.1)", "Si4 Ir4\n(1.1.0)", "In4 Ag2\n(1.1.0)", "V4 Co4 Si4\n(1.0.0)", "Ag3 Pd1\n(1.1.2)", "Sn2 Pt1\n(1.1.1)", "Cu2 Pd1 Au1\n(2.1.0)", "In4 Ag2\n(1.0.1)", "In1 Cu1 Pd2\n(2.1.0)", "Ga10 Rh6\n(0.0.1)", "V4 Sn4 Rh8\n(1.0.1)", "Si2 Ni1\n(2.1.0)", "In3 Pd2\n(0.0.1)", "N4\n(1.1.0)", "Al2 Fe1 Ir1\n(2.1.0)", "Ga1 Cu1 Rh2\n(2.1.0)", "Co2 Sn4\n(1.1.0)", "V6 N3\n(0.0.1)", "In1 Sb1\n(1.1.1)", "Ni2 Pt2\n(2.1.1)", "V6 Ni2\n(1.0.0)", "Ga2 Pt6\n(1.1.0)", "Ni2 Sb4\n(1.0.0)", "Si3 Pd6\n(0.0.1)", "In2 Au1\n(1.1.1)", "Re2 Rh6\n(0.0.1)", "Ni2 H1\n(1.0.1)", "V6 Ga2\n(1.0.0)", "Al1 Ga1 N2\n(2.1.1)", "Sn4 Pd4\n(1.0.2)", "Ni4 W1\n(1.1.1)", "Ga18 Ir4\n(0.0.1)", "Ga4 Au4\n(1.0.0)", "Ga1 Co1\n(2.1.0)", "Si4 Rh4\n(1.0.0)", "Al3 V1\n(1.1.0)", "V1 Ga1 Ni2\n(2.1.0)", "Fe1 Si2\n(1.0.0)", "In2 Sb2\n(1.0.2)", "Ga2 N2\n(1.1.1)", "Ga1 Cu1 Pt2\n(1.1.1)", "Ga4 Os2\n(0.1.0)", "Al1 Au2\n(1.1.2)", "Co2 Re6\n(0.0.1)", "Re6 Pt2\n(0.0.1)", "In2 Sb2\n(0.0.1)", "Pd1 Au3\n(2.1.1)", "V2 Ir2\n(1.0.1)", "Fe1 Si2\n(2.1.0)", "Fe3 Pt1 N1\n(1.1.1)", "Si4 Pt4\n(1.0.0)", "Co1 Si2\n(2.1.0)", "Sb1 Pd3\n(2.1.0)", "In12 Ir4\n(1.0.0)", "V1 Co1 Sb1\n(2.1.0)", "Fe8 W4\n(0.0.1)", "Ni2 Sn4 Au1\n(1.0.1)", "Sn2 Pt1\n(1.0.0)", "Co3 Sn3\n(0.0.1)", "Sn1 Pt3\n(1.1.1)", "Si2 Ni2\n(2.1.0)", "Al4 Pt4\n(1.0.0)", "Si6 H18 N2\n(0.0.1)", "Al2 Os1\n(1.1.2)", "Fe2 Pd2\n(2.1.1)", "Cu2 Sn2\n(1.1.1)", "Si4 Pd4\n(1.1.1)", "In2 Sb2\n(1.0.1)", "Si4 Os4\n(1.0.0)", "V2 Sb4\n(1.0.1)", "Al2 Fe1 Ni1\n(2.1.0)", "In12 Ir4\n(0.0.1)", "W4 N8\n(0.0.1)", "Al4 Cu2\n(1.0.1)", "Sn2 Ir1\n(1.0.0)", "In2 Pt1\n(1.1.1)", "In3 Ni2\n(1.1.1)", "Si4 Os4\n(1.1.1)", "Al18 Co4\n(0.0.1)", "Al2 Co1 Ir1\n(2.1.0)", "Si2 Ni2\n(2.1.1)", "Al18 Rh4\n(0.0.1)", "Ni2 Pt2\n(1.0.0)", "In2 Au3\n(0.0.1)", "Al1 Cu1 Pt2\n(1.1.1)", "In1 Ag3\n(1.1.1)", "Si2 Cu6\n(0.0.1)", "Fe3 Co1\n(1.1.1)", "Cu1 Ni1 Sb2\n(1.1.1)", "Al12 Fe2\n(0.0.1)", "Ga3 Ni5\n(0.0.1)", "In2 Au1\n(1.1.0)", "Re6 Pd2\n(1.0.0)", "Al2 V6\n(1.0.0)", "V1 Pd2\n(1.1.0)", "Ag3 Pd1\n(1.1.0)", "V1 Cu1 Rh2\n(2.1.0)", "Co1 Sn1 Rh2\n(1.1.2)", "In2 N2\n(1.1.0)", "In2 Au3\n(1.0.0)", "Al1 Fe1 Rh2\n(2.1.0)", "Si4 Pd12\n(0.0.1)", "Sn2\n(1.1.1)", "Fe1 Ni3\n(1.1.1)", "Si8 Sb8 Pt8\n(0.0.1)", "Fe1 Pt1\n(2.1.1)", "Al4 Cu2\n(1.1.0)", "Al2 Co1 Os1\n(2.1.0)", "Co6 Pt2\n(0.0.1)", "Ga3 Ag6\n(1.0.1)", "In1 Sb1\n(1.1.0)", "V2 Rh6\n(0.0.1)", "Pt2 W1\n(1.1.2)", "Re4 Si4\n(1.1.1)", "V2 Re1 W1\n(2.1.0)", "Al1 Cu1 Au2\n(2.1.0)", "Ni3 Sn4\n(1.1.0)", "Al2 Ir1 Os1\n(2.1.0)", "Si3 Pd6\n(1.1.1)", "Si2 Ni2\n(0.1.0)", "V2 Rh2\n(1.0.1)", "Sb1 Pt7\n(1.0.0)", "Co4 N2\n(0.1.0)", "Ga1 Sb1\n( ...
